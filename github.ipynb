# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
cd '/gdrive/MyDrive/Colab Notebooks/deepLearning/'
# Out:
# /gdrive/MyDrive/Colab Notebooks/deepLearning

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /gdrive/My Drive/Colab Notebooks/deepLearning/.git/

# %%
# !git config --global user.email "min050410@gmail.com"
# !git config --global user.name "min050410"

# %%
# !git add .

# %%
# !git commit -m "비번숨김"
# Out:
# [master 45b2c51] 비번숨김
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite github.ipynb (61%)

# %%
# !git remote add origin https://min050410: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@github.com/min050410/DeepLearning.git #add할때 비번 숨기고 연결할때 다시 비번

# %%
# !git push origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 958 bytes | 958.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/min050410/DeepLearning.git
#    32e967a..45b2c51  master -> master

# %%
# !git remote rm origin
