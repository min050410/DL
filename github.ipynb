# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd '/gdrive/MyDrive/Colab Notebooks/deepLearning/'
# Out:
# /gdrive/MyDrive/Colab Notebooks/deepLearning

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /gdrive/My Drive/Colab Notebooks/deepLearning/.git/

# %%
# !git config --global user.email "min050410@gmail.com"
# !git config --global user.name "min050410"

# %%
# !git add .
# Out:
# error: open(".gitignore.gdoc"): Operation not supported
# error: unable to index file .gitignore.gdoc
# fatal: adding files failed

# %%
# !git commit -m "ig"
# Out:
# On branch master
# Changes not staged for commit:
# 	modified:   github.ipynb
#
# Untracked files:
# 	.gitignore.gdoc
#
# no changes added to commit

# %%
# !git remote add origin https://min050410:비밀번호@github.com/min050410/DeepLearning.git

# %%
# !git push origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.12 KiB | 381.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/min050410/DeepLearning.git
#    d79f4cf..32e967a  master -> master

# %%
# !git remote rm origin
