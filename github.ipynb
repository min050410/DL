# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd '/gdrive/MyDrive/Colab Notebooks/deepLearning/'
# Out:
# /gdrive/MyDrive/Colab Notebooks/deepLearning

# %%
# !echo "# 2021-1-Classification_4classes" >> README.md
# !git init
# !git add .
# !git add README.md
# !git commit -m "Colab_first_commit"
# !git branch -M main
# !git remote add origin https://github.com/min050410/DeepLearning.git
# Out:
# Initialized empty Git repository in /gdrive/My Drive/Colab Notebooks/deepLearning/.git/
# On branch master
#
# Initial commit
#
# Untracked files:
# 	BreamAndSmelt.ipynb
# 	corona.ipynb
# 	data.ipynb
# 	github.ipynb
# 	mnist_deeplearning.ipynb
#
# nothing added to commit but untracked files present
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/min050410/DeepLearning.git'

# %%
# !git config --global user.email "min050410@gmail.com"
# !git config --global user.name "min050410"

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/min050410/DeepLearning.git'
